# %%
import pandas as pd

# %%
df=pd.read_csv("E:\mini_project_progress\weather_data_nyc_centralpark_2016(1).csv")

# %%
df
# Out:
#            date  maximum temperature  minimum temperature  \
# 0      1-1-2016                   42                   34
# 1      2-1-2016                   40                   32
# 2      3-1-2016                   45                   35
# 3      4-1-2016                   36                   14
# 4      5-1-2016                   29                   11
# ..          ...                  ...                  ...
# 361  27-12-2016                   60                   40
# 362  28-12-2016                   40                   34
# 363  29-12-2016                   46                   33
# 364  30-12-2016                   40                   33
# 365  31-12-2016                   44                   31
#
#      average temperature precipitation snow fall snow depth
# 0                   38.0          0.00       0.0          0
# 1                   36.0          0.00       0.0          0
# 2                   40.0          0.00       0.0          0
# ...

# %%
df["maximum temperature"].mean()
# Out:
# 64.6256830601093

# %%
df["date"][df["minimum temperature"]==33]
# Out:
# 37       7-2-2016
# 360    26-12-2016
# 363    29-12-2016
# 364    30-12-2016
# Name: date, dtype: object

# %%
df["maximum temperature"].fillna(0,inplace=True)

# %%
df.head(12)
# Out:
#          date  maximum temperature  minimum temperature  average temperature  \
# 0    1-1-2016                   42                   34                 38.0
# 1    2-1-2016                   40                   32                 36.0
# 2    3-1-2016                   45                   35                 40.0
# 3    4-1-2016                   36                   14                 25.0
# 4    5-1-2016                   29                   11                 20.0
# 5    6-1-2016                   41                   25                 33.0
# 6    7-1-2016                   46                   31                 38.5
# 7    8-1-2016                   46                   31                 38.5
# 8    9-1-2016                   47                   40                 43.5
# 9   10-1-2016                   59                   40                 49.5
# 10  11-1-2016                   40                   26                 33.0
# ...

# %%
df.shape
# Out:
# (366, 7)

# %%
df.columns
# Out:
# Index(['date', 'maximum temperature', 'minimum temperature',
#        'average temperature', 'precipitation', 'snow fall', 'snow depth'],
#       dtype='object')

# %%
df.head()
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 0  1-1-2016                   42                   34                 38.0
# 1  2-1-2016                   40                   32                 36.0
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
#
#   precipitation snow fall snow depth
# 0          0.00       0.0          0
# 1          0.00       0.0          0
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0

# %%
df.tail()
# Out:
#            date  maximum temperature  minimum temperature  \
# 361  27-12-2016                   60                   40
# 362  28-12-2016                   40                   34
# 363  29-12-2016                   46                   33
# 364  30-12-2016                   40                   33
# 365  31-12-2016                   44                   31
#
#      average temperature precipitation snow fall snow depth
# 361                 50.0             0         0          0
# 362                 37.0             0         0          0
# 363                 39.5          0.39         0          0
# 364                 36.5          0.01         T          0
# 365                 37.5             0         0          0

# %%
df[2:6]
# Out:
#        date  maximum temperature  minimum temperature  average temperature  \
# 2  3-1-2016                   45                   35                 40.0
# 3  4-1-2016                   36                   14                 25.0
# 4  5-1-2016                   29                   11                 20.0
# 5  6-1-2016                   41                   25                 33.0
#
#   precipitation snow fall snow depth
# 2          0.00       0.0          0
# 3          0.00       0.0          0
# 4          0.00       0.0          0
# 5          0.00       0.0          0

# %%
df["date"]
# Out:
# 0        1-1-2016
# 1        2-1-2016
# 2        3-1-2016
# 3        4-1-2016
# 4        5-1-2016
#           ...
# 361    27-12-2016
# 362    28-12-2016
# 363    29-12-2016
# 364    30-12-2016
# 365    31-12-2016
# Name: date, Length: 366, dtype: object

# %%
df["date"].head()
# Out:
# 0    1-1-2016
# 1    2-1-2016
# 2    3-1-2016
# 3    4-1-2016
# 4    5-1-2016
# Name: date, dtype: object

# %%
df[["date","minimum temperature"]]
# Out:
#            date  minimum temperature
# 0      1-1-2016                   34
# 1      2-1-2016                   32
# 2      3-1-2016                   35
# 3      4-1-2016                   14
# 4      5-1-2016                   11
# ..          ...                  ...
# 361  27-12-2016                   40
# 362  28-12-2016                   34
# 363  29-12-2016                   33
# 364  30-12-2016                   33
# 365  31-12-2016                   31
#
# [366 rows x 2 columns]

# %%
df.describe()
# Out:
#        maximum temperature  minimum temperature  average temperature
# count           366.000000           366.000000           366.000000
# mean             64.625683            49.806011            57.215847
# std              18.041787            16.570747            17.124760
# min              15.000000            -1.000000             7.000000
# 25%              50.000000            37.250000            44.000000
# 50%              64.500000            48.000000            55.750000
# 75%              81.000000            65.000000            73.500000
# max              96.000000            81.000000            88.500000

# %%
df["date"][df["maximum temperature"]>90]
# Out:
# 148    28-5-2016
# 187     6-7-2016
# 199    18-7-2016
# 203    22-7-2016
# 204    23-7-2016
# 205    24-7-2016
# 206    25-7-2016
# 208    27-7-2016
# 209    28-7-2016
# 223    11-8-2016
# 224    12-8-2016
# 225    13-8-2016
# 226    14-8-2016
# 227    15-8-2016
# 241    29-8-2016
# 252     9-9-2016
# 257    14-9-2016
# Name: date, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
df
# Out:
#                            date  minimum temperature  average temperature  \
# maximum temperature
# 42                     1-1-2016                   34                 38.0
# 40                     2-1-2016                   32                 36.0
# 45                     3-1-2016                   35                 40.0
# 36                     4-1-2016                   14                 25.0
# 29                     5-1-2016                   11                 20.0
# ...                         ...                  ...                  ...
# 60                   27-12-2016                   40                 50.0
# 40                   28-12-2016                   34                 37.0
# 46                   29-12-2016                   33                 39.5
# 40                   30-12-2016                   33                 36.5
# 44                   31-12-2016                   31                 37.5
#
#                     precipitation snow fall snow depth
# ...

# %%
df.reset_index()
# Out:
#      maximum temperature        date  minimum temperature  \
# 0                     42    1-1-2016                   34
# 1                     40    2-1-2016                   32
# 2                     45    3-1-2016                   35
# 3                     36    4-1-2016                   14
# 4                     29    5-1-2016                   11
# ..                   ...         ...                  ...
# 361                   60  27-12-2016                   40
# 362                   40  28-12-2016                   34
# 363                   46  29-12-2016                   33
# 364                   40  30-12-2016                   33
# 365                   44  31-12-2016                   31
#
#      average temperature precipitation snow fall snow depth
# 0                   38.0          0.00       0.0          0
# 1                   36.0          0.00       0.0          0
# 2                   40.0          0.00       0.0          0
# ...
