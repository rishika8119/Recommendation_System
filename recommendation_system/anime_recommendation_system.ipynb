# %%
import numpy as np
import pandas as pd

# %%
anime=pd.read_csv("Anime_data.csv")
anime
# Out:
#        Anime_id                                            Title  \
# 0             1                                     Cowboy Bebop
# 1             5                  Cowboy Bebop: Tengoku no Tobira
# 2             6                                           Trigun
# 3             7                               Witch Hunter Robin
# 4             8                                   Bouken Ou Beet
# ...         ...                                              ...
# 16997     27499  Sore Ike! Anpanman: Anpanman to Kaizoku Lobster
# 16998     12091                                         X Bomber
# 16999     29133                                   X Bomber Pilot
# 17000     34485                                       Ganko-chan
# 17001     32713                            Original C-V-P Momoko
#
#                                                    Genre  \
# 0      ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...
# 1      ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']
# ...

# %%
anime.tail(45)
# Out:
#        Anime_id                                              Title Genre  \
# 16957     14749     Ore no Kanojo to Osananajimi ga Shuraba Sugiru   NaN
# 16958      2803                         Densetsu no Yuusha Da Garn   NaN
# 16959     10447                                      Aquarion Evol   NaN
# 16960      2920                              Ashita no Joe (Movie)   NaN
# 16961     14829                     Fate/kaleid liner Prisma☆Illya   NaN
# 16962      9055                                           Tamayura   NaN
# 16963     10321                Uta no☆Prince-sama♪ Maji Love 1000%   NaN
# 16964      1259           Saint Seiya: Tenkai-hen Josou - Overture   NaN
# 16965       713                                          Air Movie   NaN
# 16966     13599                                     Robotics;Notes   NaN
# 16967      8676                                         Amagami SS   NaN
# 16968       355                                  Shakugan no Shana   NaN
# ...

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17002 entries, 0 to 17001
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Anime_id    17002 non-null  int64
#  1   Title       17002 non-null  object
#  2   Genre       14990 non-null  object
#  3   Synopsis    15583 non-null  object
#  4   Type        16368 non-null  object
#  5   Producer    7635 non-null   object
#  6   Studio      7919 non-null   object
#  7   Rating      14425 non-null  float64
#  8   ScoredBy    13227 non-null  float64
#  9   Popularity  16368 non-null  float64
#  10  Members     17002 non-null  float64
#  11  Episodes    14085 non-null  float64
#  12  Source      15075 non-null  object
#  13  Aired       16368 non-null  object
#  14  Link        16368 non-null  object
# dtypes: float64(5), int64(1), object(9)
# memory usage: 1.9+ MB

# %%
anime.shape
# Out:
# (17002, 15)

# %%
anime.isnull().sum()
# Out:
# Anime_id         0
# Title            0
# Genre         2012
# Synopsis      1419
# Type           634
# Producer      9367
# Studio        9083
# Rating        2577
# ScoredBy      3775
# Popularity     634
# Members          0
# Episodes      2917
# Source        1927
# Aired          634
# Link           634
# dtype: int64

# %%
anime=anime[["Title","Genre","Rating","Studio","Episodes","Source","Synopsis"]]

# %%
anime
# Out:
#                                                  Title  \
# 0                                         Cowboy Bebop
# 1                      Cowboy Bebop: Tengoku no Tobira
# 2                                               Trigun
# 3                                   Witch Hunter Robin
# 4                                       Bouken Ou Beet
# ...                                                ...
# 16997  Sore Ike! Anpanman: Anpanman to Kaizoku Lobster
# 16998                                         X Bomber
# 16999                                   X Bomber Pilot
# 17000                                       Ganko-chan
# 17001                            Original C-V-P Momoko
#
#                                                    Genre  Rating  \
# 0      ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...    8.81
# 1      ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']    8.41
# 2      ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...    8.31
# ...

# %%
anime.shape
# Out:
# (17002, 7)

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17002 entries, 0 to 17001
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     17002 non-null  object
#  1   Genre     14990 non-null  object
#  2   Rating    14425 non-null  float64
#  3   Studio    7919 non-null   object
#  4   Episodes  14085 non-null  float64
#  5   Source    15075 non-null  object
#  6   Synopsis  15583 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 929.9+ KB

# %%
anime.isnull().sum()
# Out:
# Title          0
# Genre       2012
# Rating      2577
# Studio      9083
# Episodes    2917
# Source      1927
# Synopsis    1419
# dtype: int64

# %%
anime.dropna(inplace=True)

# %%
anime
# Out:
#                                             Title  \
# 0                                    Cowboy Bebop
# 1                 Cowboy Bebop: Tengoku no Tobira
# 2                                          Trigun
# 3                              Witch Hunter Robin
# 4                                  Bouken Ou Beet
# ...                                           ...
# 14745                Kekkaishi: Yoshimori no Omoi
# 14746  Busou Renkin: Mahiro no Busou Renkin Kouza
# 14754    Fushigiboshi no☆Futagohime: Marugoto DVD
# 14759                  Seikai no Senki II Special
# 15007                                      Yamiyo
#
#                                                    Genre  Rating  \
# 0      ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...    8.81
# 1      ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']    8.41
# 2      ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...    8.31
# 3      ['Action', 'Magic', 'Police', 'Supernatural', ...    7.34
# ...

# %%
anime.duplicated().sum()
# Out:
# 52

# %%
anime.drop_duplicates(inplace=True)

# %%
anime.duplicated().sum()
# Out:
# 0

# %%
anime.head()
# Out:
#                              Title  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                                Genre  Rating  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...    8.81
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']    8.41
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...    8.31
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...    7.34
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...    7.04
#
#                Studio  Episodes    Source  \
# 0         ['Sunrise']      26.0  Original
# 1           ['Bones']       1.0  Original
# 2        ['Madhouse']      26.0     Manga
# 3         ['Sunrise']      26.0  Original
# 4  ['Toei Animation']      52.0     Manga
#
#                                             Synopsis
# 0  In the year 2071, humanity has colonized sever...
# ...

# %%
anime["Synopsis"][0]
# Out:
# 'In the year 2071, humanity has colonized several of the planets and moons of the solar system leaving the now uninhabitable surface of planet Earth behind. The Inter Solar System Police attempts to keep peace in the galaxy, aided in part by outlaw bounty hunters, referred to as "Cowboys." The ragtag team aboard the spaceship Bebop are two such individuals. \r\n  \r\nMellow and carefree Spike Spiegel is balanced by his boisterous, pragmatic partner Jet Black as the pair makes a living chasing bounties and collecting rewards. Thrown off course by the addition of new members that they meet in their travels—Ein, a genetically engineered, highly intelligent Welsh Corgi; femme fatale Faye Valentine, an enigmatic trickster with memory loss; and the strange computer whiz kid Edward Wong—the crew embarks on thrilling adventures that unravel each member\'s dark and mysterious past little by little. \r\n \r\nWell-balanced with high density action and light-hearted comedy,  Cowboy Bebop  is a s
# ...

# %%
anime["Synopsis"] = anime["Synopsis"].apply(lambda x: x.split())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6572/2749290762.py in <module>
# ----> 1 anime["Synopsis"] = anime["Synopsis"].apply(lambda x: x.split())
#
# c:\python39\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# c:\python39\lib\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# c:\python39\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1090                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
anime
# Out:
#                                             Title  \
# 0                                    Cowboy Bebop
# 1                 Cowboy Bebop: Tengoku no Tobira
# 2                                          Trigun
# 3                              Witch Hunter Robin
# 4                                  Bouken Ou Beet
# ...                                           ...
# 14745                Kekkaishi: Yoshimori no Omoi
# 14746  Busou Renkin: Mahiro no Busou Renkin Kouza
# 14754    Fushigiboshi no☆Futagohime: Marugoto DVD
# 14759                  Seikai no Senki II Special
# 15007                                      Yamiyo
#
#                                                    Genre  Rating  \
# 0      ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...    8.81
# 1      ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']    8.41
# 2      ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...    8.31
# 3      ['Action', 'Magic', 'Police', 'Supernatural', ...    7.34
# ...

# %%
anime["Studio"].apply(lambda x:[i.replace(" ","") for i in x])
# Out:
# 0                        [[, ', S, u, n, r, i, s, e, ', ]]
# 1                              [[, ', B, o, n, e, s, ', ]]
# 2                     [[, ', M, a, d, h, o, u, s, e, ', ]]
# 3                        [[, ', S, u, n, r, i, s, e, ', ]]
# 4        [[, ', T, o, e, i, , A, n, i, m, a, t, i, o, n...
#                                ...
# 14745                    [[, ', S, u, n, r, i, s, e, ', ]]
# 14746                          [[, ', X, e, b, e, c, ', ]]
# 14754    [[, ', H, a, l, , F, i, l, m, , M, a, k, e, r,...
# 14759                    [[, ', S, u, n, r, i, s, e, ', ]]
# 15007         [[, ', T, w, i, n, , E, n, g, i, n, e, ', ]]
# Name: Studio, Length: 7244, dtype: object

# %%
anime.head()
# Out:
#                              Title  \
# 0                     Cowboy Bebop
# 1  Cowboy Bebop: Tengoku no Tobira
# 2                           Trigun
# 3               Witch Hunter Robin
# 4                   Bouken Ou Beet
#
#                                                Genre  Rating  \
# 0  ['Action', 'Adventure', 'Comedy', 'Drama', 'Sc...    8.81
# 1  ['Action', 'Space', 'Drama', 'Mystery', 'Sci-Fi']    8.41
# 2  ['Action', 'Sci-Fi', 'Adventure', 'Comedy', 'D...    8.31
# 3  ['Action', 'Magic', 'Police', 'Supernatural', ...    7.34
# 4  ['Adventure', 'Fantasy', 'Shounen', 'Supernatu...    7.04
#
#                Studio  Episodes    Source  \
# 0         ['Sunrise']      26.0  Original
# 1           ['Bones']       1.0  Original
# 2        ['Madhouse']      26.0     Manga
# 3         ['Sunrise']      26.0  Original
# 4  ['Toei Animation']      52.0     Manga
#
#                                             Synopsis
# 0  [In, the, year, 2071,, humanity, has, colonize...
# ...
