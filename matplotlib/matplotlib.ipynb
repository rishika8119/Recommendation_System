# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=[1,5,6,4,7,8,9]
y=[8,14,5,2,3,6,5]

# %%
plt.xlabel=("day")
plt.ylabel("temperature")
plt.title("weather")
plt.plot(x,y,color="green",linewidth=2)
